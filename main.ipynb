# %%
from src.simulator import Simulator
HR_MODEL_PATH = "stretch3/scene.xml"
sim = Simulator(HR_MODEL_PATH)
sim.run_sim(camera='camera_rgb_wrist')
# Out:
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# Rendering camera: None
# Rendering camera: camera_rgb
# Rendering camera: camera_depth
# Rendering camera: camera_rgb_wrist
# Rendering camera: camera_depth_wrist
# ...
